# %%
import pandas as pd 
from pandas import Series,DataFrame
top_of_youtuber_df=pd.read_csv('top-5000-youtube-channels-data-from-socialblade.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b4198112b0ee> in <module>
# ----> 1 import pandas as pd
#       2 from pandas import Series,DataFrame
#       3 top_of_youtuber_df=pd.read_csv('top-5000-youtube-channels-data-from-socialblade.csv')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
top_of_youtuber_df.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
top_of_youtuber_df
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# 5         6th  A++                         Movieclips         30243
# 6         7th  A++                         netd müzik          8500
# 7         8th  A++              ABS-CBN Entertainment        100147
# 8         9th  A++                    Ryan ToysReview          1140
# 9        10th  A++                        Zee Marathi         74607
# 10       11th   A+                    5-Minute Crafts          2085
# 11       12th   A+                    Canal KondZilla           822
# 12       13th   A+                   Like Nastya Vlog           150
# ...

# %%
Channel_name=top_of_youtuber_df['Channel name']

# %%
Channel_name.head()
# Out:
# 0                        Zee TV
# 1                      T-Series
# 2    Cocomelon - Nursery Rhymes
# 3                     SET India
# 4                           WWE
# Name: Channel name, dtype: object

# %%
names=[]
for name in Channel_name:
    names.append(name[0])

# %%
names
# Out:
# ['Z',
#  'T',
#  'C',
#  'S',
#  'W',
#  'M',
#  'n',
#  'A',
#  'R',
#  'Z',
#  '5',
#  'C',
#  'L',
#  'O',
#  'W',
#  'C',
#  'W',
#  'V',
#  'B',
#  'W',
#  'x',
#  'Z',
#  'S',
#  'D',
#  'E',
#  'S',
#  'i',
#  'E',
#  'Z',
#  'K',
#  'Z',
#  'S',
#  'T',
#  'I',
#  'T',
#  'C',
#  'G',
#  'o',
#  '[',
#  'C',
#  'G',
#  'Z',
#  'I',
#  'G',
#  'R',
#  'B',
#  'S',
#  'G',
#  'S',
#  'I',
#  'T',
#  'T',
#  'T',
#  'U',
#  'L',
#  '✿',
#  'B',
#  'C',
#  'M',
#  'ا',
#  'P',
#  '1',
#  'P',
#  'E',
#  'S',
#  'B',
#  'P',
#  'S',
#  'G',
#  'B',
#  'V',
#  'D',
#  'F',
#  'E',
#  'М',
#  'D',
#  'A',
#  'E',
#  'C',
#  'O',
#  'C',
#  'G',
#  'S',
#  'F',
#  'G',
#  'Y',
#  'D',
#  'キ',
#  'L',
#  'Z',
#  'L',
#  'A',
#  'h',
#  'B',
#  'T',
#  'L',
#  'N',
#  'M',
#  'B',
#  'G',
#  'L',
#  'H',
#  'D',
#  'A',
#  'S',
#  'm',
#  'R',
#  'V',
#  'B',
#  'B',
#  'Д',
#  'W',
#  'I',
#  'W',
#  'C',
#  'B',
#  'ق',
#  'V',
#  'S',
#  'B',
#  'B',
#  's',
#  'S',
#  'F',
#  'A',
# ...

# %%
name_df=DataFrame(names)
name_df.columns=['Channel name']

# %%
name_df
# Out:
#      Channel name
# 0               Z
# 1               T
# 2               C
# 3               S
# 4               W
# 5               M
# 6               n
# 7               A
# 8               R
# 9               Z
# 10              5
# 11              C
# 12              L
# 13              O
# 14              W
# 15              C
# 16              W
# 17              V
# 18              B
# 19              W
# 20              x
# 21              Z
# 22              S
# 23              D
# 24              E
# 25              S
# 26              i
# 27              E
# 28              Z
# 29              K
# ...           ...
# 4970            C
# 4971            S
# 4972            F
# 4973            ข
# 4974            R
# 4975            F
# 4976            A
# 4977            D
# 4978            Р
# 4979            M
# 4980            S
# 4981            L
# 4982            채
# 4983            М
# 4984            J
# 4985            A
# 4986            C
# 4987            Y
# ...

# %%
sns.countplot('Channel name',data=name_df,palette='winter_d',order=sorted(set(names)))
